# %%
import pandas as pd

# %%
df_2022 = pd.read_csv('https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2022.csv')
# Out:
# /var/folders/5p/7rl6w2q54h71cb6zlvtpc8m00000gp/T/ipykernel_83151/3432169182.py:1: DtypeWarning: Columns (179,180,182,183,189,190,193,194,197,198,203,204,205,206,218,219,220,222,224,226,243,244,245,253,254,255,260,262,263,283,284,301) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv('https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_2022.csv')

# %%
df_2022
# Out:
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 1           43  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 2           68  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 3           89  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 4          115  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# ...        ...              ...          ...       ...       ...         ...
# 50142     4035   2022_22_KC_PHI   2023021200       PHI        KC        POST
# 50143     4024   2022_22_KC_PHI   2023021200       PHI        KC        POST
# 50144     4050   2022_22_KC_PHI   2023021200       PHI        KC        POST
# 50145     4072   2022_22_KC_PHI   2023021200       PHI        KC        POST
# 50146     4094   2022_22_KC_PHI   2023021200       PHI        KC        POST
#
# ...

# %%
df_2022[['desc', 'play']]
# Out:
#                                                     desc  play
# 0                                                   GAME     0
# 1      9-J.Tucker kicks 68 yards from BAL 35 to NYJ -...     0
# 2      (14:56) 32-Mi.Carter left end to NYJ 41 for 19...     1
# 3      (14:29) (No Huddle, Shotgun) 19-J.Flacco pass ...     1
# 4      (14:25) (No Huddle, Shotgun) 32-Mi.Carter left...     1
# ...                                                  ...   ...
# 50142                         Timeout #3 by KC at 00:11.     0
# 50143  (:11) 7-H.Butker 27 yard field goal is GOOD, C...     0
# 50144  7-H.Butker kicks 40 yards from KC 35 to PHI 25...     0
# 50145  (:06) (Shotgun) 1-J.Hurts pass incomplete deep...     1
# 50146                                           END GAME     0
#
# [50147 rows x 2 columns]
